# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

# %%
df = pd.read_csv("/kaggle/input/housesalesprediction/kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.countplot(x ='bedrooms',data = df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.boxplot(x='bedrooms',y = 'price',data = df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(x = 'price',y='long',data = df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
sns.scatterplot(x = 'price',y='lat',data = df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x = 'long',y='lat',hue = 'price',data = df,alpha = 0.2,palette='viridis')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.displot(x= 'price',data = df,bins=100)

# %%
len(df)*0.01
# Out:
# 216.13

# %%
df['price'].sort_values(ascending = False)
# Out:
# 7252     7700000.0
# 3914     7062500.0
# 9254     6885000.0
# 4411     5570000.0
# 1448     5350000.0
#            ...
# 8274       82000.0
# 16198      81000.0
# 465        80000.0
# 15293      78000.0
# 1149       75000.0
# Name: price, Length: 21613, dtype: float64

# %%
df1 = df.sort_values('price',ascending = False).loc[217:]

# %%
df1.shape
# Out:
# (10587, 21)

# %%
sns.displot(x='price', data=df1, bins=50)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(),annot=True,cmap='viridis')
# Out:
# /tmp/ipykernel_20/3046901707.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True,cmap='viridis')
# <Axes: >

# %%
df1.corr()['price'].sort_values(ascending=False)
# Out:
# /tmp/ipykernel_20/3280954361.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()['price'].sort_values(ascending=False)
# price            1.000000
# lat              0.433614
# grade            0.392878
# sqft_living      0.356758
# sqft_living15    0.313922
# bathrooms        0.312624
# sqft_above       0.286787
# floors           0.223165
# bedrooms         0.165772
# yr_built         0.157314
# sqft_basement    0.154008
# view             0.081635
# zipcode          0.051301
# sqft_lot         0.040710
# long             0.038295
# sqft_lot15       0.035064
# waterfront       0.019896
# id               0.015003
# yr_renovated     0.005041
# condition       -0.020219
# Name: price, dtype: float64

# %%
df1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1 = df1.drop(['zipcode','id'],axis = 1)

# %%
df1['date']
# Out:
# 217      20140703T000000
# 13106    20140527T000000
# 6368     20140630T000000
# 7604     20141014T000000
# 16923    20140502T000000
#               ...
# 8274     20141105T000000
# 16198    20150324T000000
# 465      20140523T000000
# 15293    20140506T000000
# 1149     20150217T000000
# Name: date, Length: 10587, dtype: object

# %%
df1['date'] = df1['date'].apply(lambda x : x.split('T')[0])

# %%
df1['date']
# Out:
# 217      20140703
# 13106    20140527
# 6368     20140630
# 7604     20141014
# 16923    20140502
#            ...
# 8274     20141105
# 16198    20150324
# 465      20140523
# 15293    20140506
# 1149     20150217
# Name: date, Length: 10587, dtype: object

# %%
df1['date'] = pd.to_datetime(df['date'])

# %%
df1.head()
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 217   2014-07-03  445838.0         3       2.50         2250      5692
# 13106 2014-05-27  445830.0         3       2.50         1870      5449
# 6368  2014-06-30  445800.0         4       2.25         2070     39446
# 7604  2014-10-14  445800.0         3       2.00         1320      6500
# 16923 2014-05-02  445700.0         3       2.50         1270      1180
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 217       2.0           0     0          3      8        2250              0
# 13106     2.0           0     0          3      8        1870              0
# 6368      1.0           0     0          3      8        1470            600
# 7604      1.0           0     0          3      7        1320              0
# 16923     3.0           0     0          3      8        1270              0
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df1['year'] = df1['date'].apply(lambda x: x.year)
df1['months'] = df1['date'].apply(lambda x: x.month)

# %%
df1.head()
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 217   2014-07-03  445838.0         3       2.50         2250      5692
# 13106 2014-05-27  445830.0         3       2.50         1870      5449
# 6368  2014-06-30  445800.0         4       2.25         2070     39446
# 7604  2014-10-14  445800.0         3       2.00         1320      6500
# 16923 2014-05-02  445700.0         3       2.50         1270      1180
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 217       2.0           0     0          3  ...        2250              0
# 13106     2.0           0     0          3  ...        1870              0
# 6368      1.0           0     0          3  ...        1470            600
# 7604      1.0           0     0          3  ...        1320              0
# 16923     3.0           0     0          3  ...        1270              0
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df1 = df1.drop('date',axis = 1)

# %%
df1
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 217    445838.0         3       2.50         2250      5692     2.0
# 13106  445830.0         3       2.50         1870      5449     2.0
# 6368   445800.0         4       2.25         2070     39446     1.0
# 7604   445800.0         3       2.00         1320      6500     1.0
# 16923  445700.0         3       2.50         1270      1180     3.0
# ...         ...       ...        ...          ...       ...     ...
# 8274    82000.0         3       1.00          860     10426     1.0
# 16198   81000.0         2       1.00          730      9975     1.0
# 465     80000.0         1       0.75          430      5050     1.0
# 15293   78000.0         2       1.00          780     16344     1.0
# 1149    75000.0         1       0.00          670     43377     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 217             0     0          3      8        2250              0
# ...

# %%
x = df1.drop('price',axis = 1).values
y = df1['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train
# Out:
# array([[2.000e+00, 1.000e+00, 1.010e+03, ..., 7.800e+03, 2.015e+03,
#         5.000e+00],
#        [2.000e+00, 1.750e+00, 1.950e+03, ..., 8.000e+03, 2.015e+03,
#         3.000e+00],
#        [3.000e+00, 1.000e+00, 1.030e+03, ..., 8.400e+03, 2.015e+03,
#         3.000e+00],
#        ...,
#        [3.000e+00, 1.000e+00, 9.600e+02, ..., 8.100e+03, 2.014e+03,
#         5.000e+00],
#        [4.000e+00, 3.500e+00, 2.380e+03, ..., 5.775e+03, 2.014e+03,
#         1.000e+01],
#        [2.000e+00, 2.500e+00, 1.700e+03, ..., 6.635e+03, 2.014e+03,
#         1.000e+01]])

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# ...

# %%
x_train.shape
# Out:
# (7410, 19)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))
          
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x = x_train,y = y_train,validation_data=(x_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 58/58 [==============================] - 2s 7ms/step - loss: 105465823232.0000 - val_loss: 106188537856.0000
# Epoch 2/400
# 58/58 [==============================] - 0s 4ms/step - loss: 105430179840.0000 - val_loss: 106062462976.0000
# Epoch 3/400
# 58/58 [==============================] - 0s 3ms/step - loss: 104756576256.0000 - val_loss: 104177926144.0000
# Epoch 4/400
# 58/58 [==============================] - 0s 3ms/step - loss: 98790424576.0000 - val_loss: 91210194944.0000
# Epoch 5/400
# 58/58 [==============================] - 0s 3ms/step - loss: 71999643648.0000 - val_loss: 47374553088.0000
# Epoch 6/400
# 58/58 [==============================] - 0s 4ms/step - loss: 21973002240.0000 - val_loss: 5872884224.0000
# Epoch 7/400
# 58/58 [==============================] - 0s 3ms/step - loss: 4837230592.0000 - val_loss: 4648779776.0000
# Epoch 8/400
# 58/58 [==============================] - 0s 3ms/step - loss: 4673588224.0000 - val_loss: 4602127360.0000
# Epoch 9/400
# ...

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <Axes: >

# %%
predict = model.predict(x_test)
# Out:
# 100/100 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test, predict))
# Out:
# 40982.40933368744

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test,predict)
plt.plot(y_test,y_test,'r')

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predit = lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test, predit))
# Out:
# 40942.89742609791

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test,predit)
plt.plot(y_test,y_test,'r')
